# %% [markdown]
# **CONFIRGURAÇÕES INICIAS:**

# %%
# !pip install -q -U google-generativeai

# %%
#BIBLIOTECA USADA
import os
import google.generativeai as genai
from time import sleep
from tqdm import tqdm
from termcolor import colored

# CHAVE API KEY
os.environ['API_KEY'] = 'AIzaSyALIm_uVj79Kss2Oj0RYp9G6eolyma8EfA'
genai.configure(api_key=os.environ['API_KEY'])
model = genai.GenerativeModel('gemini-pro')

# %% [markdown]
# **CRIAÇÃO DO CHATBOT:**

# %%
# Funções do chatbot

def criar_plano_de_estudo(disciplinas, horas_estudo):
    # O chatbot usa o Gemini API para criar um plano de estudo personalizado
    for _ in tqdm(range(10), desc="Criando plano...", ncols=80):
        sleep(0.2)

    prompt = f"Criar um plano de estudo detalhado para as disciplinas: {disciplinas}. O plano deve considerar {horas_estudo} horas de estudo por semana."
    response = model.generate_content(prompt)  # Certifique-se de que 'model' esteja definido
    return response.text

def responder_duvidas_tarefas(duvida):
    # O chatbot usa o Gemini API para fornecer uma resposta
    prompt = f"Responder a seguinte dúvida sobre a tarefa: {duvida}"
    response = model.generate_content(prompt)
    return response.text

def fornecer_feedback_trabalhos(trabalho):
    # O chatbot usa o Gemini API para analisar e fornecer feedback
    prompt = f"Fornecer feedback sobre o seguinte trabalho escrito: {trabalho}"
    response = model.generate_content(prompt)
    return response.text

def criar_exercicio(texto_base):
    # O chatbot usa o Gemini API para criar perguntas de exercício baseado no texto fornecido
    prompt = f"Criar perguntas de exercício baseado no seguinte texto: {texto_base}"
    response = model.generate_content(prompt)
    perguntas = response.text

    # Armazenar as respostas para uso posterior
    prompt_respostas = f"Criar as respostas para o exercício baseado no seguinte texto: {texto_base}"
    response_respostas = model.generate_content(prompt_respostas)
    respostas = response_respostas.text

    return perguntas, respostas

# %% [markdown]
# **SIMULADOR PARA INTERAÇÃO DO CHATBOT**

# %%
from termcolor import colored

while True:
    print(colored("\nBem-vindo ao Chatbot Educacional!", 'blue', attrs=['bold']))
    print("Escolha uma das opções abaixo:")
    print("1. Plano de Estudo")
    print("2. Dúvida sobre Tarefa")
    print("3. Feedback sobre Trabalho")
    print("4. Criar Exercício")
    print("5. Sair")

    escolha = input(colored("Digite o número da opção desejada: ", 'green'))

    if escolha == "1":
        print("\n" + "*" * 20 + " Plano de Estudo " + "*" * 20 + "\n")
        disciplinas = input(colored("Quais disciplinas você gostaria de incluir? ", 'yellow'))
        horas_estudo = input(colored("Quantas horas por semana você pode dedicar ao estudo? ", 'yellow'))
        print(colored("\nProcessando...", 'magenta'))
        print(criar_plano_de_estudo(disciplinas, horas_estudo))
        print("Plano de estudo criado.")

    elif escolha == "2":
        duvida = input("Qual é a sua dúvida sobre a tarefa? ")
        print(responder_duvidas_tarefas(duvida))
        print("Resposta para sua dúvida.")

    elif escolha == "3":
        trabalho = input("Por favor, cole o seu trabalho escrito aqui:\n ")
        print(fornecer_feedback_trabalhos(trabalho))
        print("Feedback para seu trabalho.")

    elif escolha == "4":
        texto_base = input("Por favor, insira o texto base para o exercício:\n ")
        perguntas, respostas = criar_exercicio(texto_base)
        print("Perguntas do exercício:\n", perguntas)
        while True:
            mostrar_resposta = input("Deseja ver as respostas agora? (sim/não): ")
            if mostrar_resposta.lower() == 'sim':
                print("Respostas do exercício:\n", respostas)
                break
            elif mostrar_resposta.lower() == 'não':
                print("Tudo bem, você pode visualizar as respostas quando estiver pronto.")
                break
            else:
                print("Por favor, responda com 'sim' ou 'não'.")
        continue

    elif escolha == "5":
        print("Saindo do Chatbot Educacional. Até a próxima!")
        break

    else:
        print(colored("Opção inválida. Tente novamente.", 'red'))
# Out:
# Bem-vindo ao Chatbot Educacional!
# Escolha uma das opções abaixo:
# 1. Plano de Estudo
# 2. Dúvida sobre Tarefa
# 3. Feedback sobre Trabalho
# 4. Criar Exercício
# 6. Sair
# Digite o número da opção desejada: 2
# Qual é a sua dúvida sobre a tarefa? o que é python?
# Python é uma linguagem de programação interpretada de alto nível e de propósito geral. É conhecida por sua sintaxe clara e simples, tornando-a fácil de aprender e usar. Python é versátil e pode ser usada para uma ampla gama de aplicações, incluindo:
#
# * Desenvolvimento de aplicativos da Web
# * Ciência de dados e aprendizado de máquina
# * Automação de tarefas
# * Desenvolvimento de software em geral
# * Prototipagem rápida
# * Análise e visualização de dados
# Resposta para sua dúvida.
#
# Bem-vindo ao Chatbot Educacional!
# Escolha uma das opções abaixo:
# 1. Plano de Estudo
# 2. Dúvida sobre Tarefa
# 3. Feedback sobre Trabalho
# 4. Criar Exercício
# 6. Sair
# Digite o número da opção desejada: 3
# Por favor, cole o seu trabalho escrito aqui:
#  2	DESENVOLVIMENTO No início do desenvolvimento do diagrama de casos de uso, precisamos definir os atores, ou seja, as entidades que interagem com o sistema. Neste caso, os atores principais são: •	Cliente: Pessoa física ou jurídica que utiliza os serviços bancários. •	Funcionário: Pode ser um gerente ou caixa do banco, auxiliando em atividades do sistema. o	A variação entre os atores é representada por uma seta de generalização, apontando para os atores principais 'Cliente' e 'Funcionário'.  Casos de Uso: •	Abrir Conta: o	O cliente procura um funcionário. o	Informa seus dados. o	Escolhe entre conta especial ou poupança (após a validação das informações). •	Encerrar Conta: o	O cliente, com saldo zero, procura um funcionário. o	Solicita o encerramento da conta. •	Depósito/Saque: o	O cliente, com conta criada, utiliza o caixa eletrônico. o	Escolhe entre realizar um saque (com saldo positivo) ou depósito. o	O banco valida e disponibiliza o valor na conta. •	Saldo/Extrato: o	O cliente, com conta criada, utiliza o caixa eletrônico. o	Solicita o saldo ou extrato. o	A opção de exibir na tela ou imprimir é disponibilizada (se houver movimentações). •	Registro de Movimentações: o	Cada operação na conta é registrada e armazenada como log de atividade.  Observe que este é um diagrama de casos de uso simplificado e pode ser expandido e detalhado conforme necessário para refletir os requisitos específicos do sistema bancário. Além disso, outros atores e casos de uso podem ser ampliados à medida que mais requisitos ou funcionalidades são identificados. A disposição completa do sistema pode ser encontrada na imagem abaixo: 3	DIAGRAMA DO SISTEMA BANCÁRIO
# **Feedback**
#
# **Pontos Fortes:**
#
# * Os atores do sistema estão claramente definidos.
# * Os casos de uso são bem descritos e fornecem uma visão geral das principais funcionalidades do sistema.
# * O diagrama do sistema fornece uma representação visual clara do sistema bancário.
#
# **Áreas de Melhoria:**
#
# **Diagrama de Casos de Uso:**
#
# * O diagrama de casos de uso poderia ser aprimorado adicionando relacionamentos entre os casos de uso, como "estende" ou "inclui", para mostrar as dependências entre eles.
# * Seria útil adicionar pré-condições e pós-condições para cada caso de uso para especificar as condições necessárias para que o caso de uso seja executado e os resultados esperados após sua execução.
#
# **Descrição dos Casos de Uso:**
#
# * As descrições dos casos de uso são concisas, mas poderiam ser aprimoradas fornecendo mais detalhes sobre os fluxos de eventos e as variações de caminho alternativas.
# * Considere adicionar um parágrafo resumindo os casos de uso e destacando quaisquer casos de uso essenciais ou críticos.
#
# **Diagrama do Sistema:**
#
# * O diagrama do sistema é claro e informativo, mas poderia ser aprimorado adicionando legendas ou rótulos aos componentes e interfaces do sistema.
# * Seria útil incluir uma breve descrição da arquitetura do sistema ou de quaisquer tecnologias específicas usadas.
#
# **Outros:**
#
# * Adicionar uma seção de glossário para definir quaisquer termos técnicos ou abreviações usados no documento.
# * Fornecer referências a quaisquer fontes ou documentos adicionais que foram consultados durante a criação do documento.
# * Garantir que o documento seja bem formatado e fácil de ler, com títulos, subtítulos e marcadores apropriados.
# Feedback para seu trabalho.
#
# Bem-vindo ao Chatbot Educacional!
# Escolha uma das opções abaixo:
# 1. Plano de Estudo
# 2. Dúvida sobre Tarefa
# 3. Feedback sobre Trabalho
# 4. Criar Exercício
# 6. Sair
# Digite o número da opção desejada: 4
# Por favor, insira o texto base para o exercício:
#  No início do desenvolvimento do diagrama de casos de uso, precisamos definir os atores, ou seja, as entidades que interagem com o sistema. Neste caso, os atores principais são: •	Cliente: Pessoa física ou jurídica que utiliza os serviços bancários. •	Funcionário: Pode ser um gerente ou caixa do banco, auxiliando em atividades do sistema. o	A variação entre os atores é representada por uma seta de generalização, apontando para os atores principais 'Cliente' e 'Funcionário'.  Casos de Uso: •	Abrir Conta: o	O cliente procura um funcionário. o	Informa seus dados. o	Escolhe entre conta especial ou poupança (após a validação das informações). •	Encerrar Conta: o	O cliente, com saldo zero, procura um funcionário. o	Solicita o encerramento da conta. •	Depósito/Saque: o	O cliente, com conta criada, utiliza o caixa eletrônico. o	Escolhe entre realizar um saque (com saldo positivo) ou depósito. o	O banco valida e disponibiliza o valor na conta. •	Saldo/Extrato: o	O cliente, com conta criada, utiliza o caixa eletrônico. o	Solicita o saldo ou extrato. o	A opção de exibir na tela ou imprimir é disponibilizada (se houver movimentações). •	Registro de Movimentações: o	Cada operação na conta é registrada e armazenada como log de atividade.  Observe que este é um diagrama de casos de uso simplificado e pode ser expandido e detalhado conforme necessário para refletir os requisitos específicos do sistema bancário. Além disso, outros atores e casos de uso podem ser ampliados à medida que mais requisitos ou funcionalidades são identificados.
# Perguntas do exercício:
#  **Perguntas de Exercício**
#
# **Atores**
#
# 1. Quais são os dois atores principais no diagrama de casos de uso fornecido?
# 2. Qual símbolo representa a variação entre os atores?
# 3. O que diferencia um "Cliente" de um "Funcionário" no contexto deste diagrama?
#
# **Casos de Uso**
#
# 4. Liste os casos de uso descritos no texto.
# 5. Para o caso de uso "Abrir Conta", quais são os passos envolvidos?
# 6. Em qual caso de uso o cliente acessa o caixa eletrônico?
# 7. Qual opção é oferecida ao cliente ao solicitar "Saldo/Extrato"?
#
# **Outros**
#
# 8. Explique o propósito de "Registro de Movimentações".
# 9. Por que os diagramas de casos de uso podem ser expandidos e detalhados?
# 10. Discuta possíveis atores e casos de uso adicionais que possam ser considerados em um diagrama de casos de uso mais abrangente para um sistema bancário.
# Deseja ver as respostas agora? (sim/não): sim
# Respostas do exercício:
#  **Exercício**
#
# Identifique os atores e casos de uso descritos no texto.
#
# **Respostas**
#
# **Atores:**
#
# * Cliente
# * Funcionário
#
# **Casos de Uso:**
#
# * Abrir Conta
# * Encerrar Conta
# * Depósito/Saque
# * Saldo/Extrato
# * Registro de Movimentações
#
# Bem-vindo ao Chatbot Educacional!
# Escolha uma das opções abaixo:
# 1. Plano de Estudo
# 2. Dúvida sobre Tarefa
# 3. Feedback sobre Trabalho
# 4. Criar Exercício
# 6. Sair
# Digite o número da opção desejada: 6
# Opção inválida. Tente novamente.
#
# Bem-vindo ao Chatbot Educacional!
# Escolha uma das opções abaixo:
# 1. Plano de Estudo
# 2. Dúvida sobre Tarefa
# 3. Feedback sobre Trabalho
# 4. Criar Exercício
# 6. Sair
# Digite o número da opção desejada: 6
# Opção inválida. Tente novamente.
#
# Bem-vindo ao Chatbot Educacional!
# Escolha uma das opções abaixo:
# 1. Plano de Estudo
# 2. Dúvida sobre Tarefa
# 3. Feedback sobre Trabalho
# 4. Criar Exercício
# 6. Sair
# Digite o número da opção desejada: 5
# Saindo do Chatbot Educacional. Até a próxima!
